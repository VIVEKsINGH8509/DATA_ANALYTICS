# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/MS_Dhoni_ODI_record.csv')
df
# Out:
#     score runs_scored balls_faced strike_rate fours sixes     opposition  \
# 0       0           0           1           0     0     0   v Bangladesh
# 1      12          12          11      109.09     2     0   v Bangladesh
# 2      7*           7           2         350     0     1   v Bangladesh
# 3       3           3           7       42.85     0     0     v Pakistan
# 4     148         148         123      120.32    15     4     v Pakistan
# ..    ...         ...         ...         ...   ...   ...            ...
# 345   56*          56          61        91.8     3     2  v West Indies
# 346   42*          42          31      135.48     4     1      v England
# 347    35          35          33      106.06     4     0   v Bangladesh
# 348   DNB           -           -           -     -     -    v Sri Lanka
# 349    50          50          72       69.44     1     1  v New Zealand
#
#             ground        date  odi_number
# 0       Chattogram  23/12/2004  ODI # 2199
# ...

# %%
df.head()
# Out:
#   score runs_scored balls_faced strike_rate fours sixes    opposition  \
# 0     0           0           1           0     0     0  v Bangladesh
# 1    12          12          11      109.09     2     0  v Bangladesh
# 2    7*           7           2         350     0     1  v Bangladesh
# 3     3           3           7       42.85     0     0    v Pakistan
# 4   148         148         123      120.32    15     4    v Pakistan
#
#           ground        date  odi_number
# 0     Chattogram  23/12/2004  ODI # 2199
# 1          Dhaka  26/12/2004  ODI # 2201
# 2          Dhaka  27/12/2004  ODI # 2202
# 3          Kochi  02/04/2005  ODI # 2235
# 4  Visakhapatnam  05/04/2005  ODI # 2236

# %%
df.tail()
# Out:
#     score runs_scored balls_faced strike_rate fours sixes     opposition  \
# 345   56*          56          61        91.8     3     2  v West Indies
# 346   42*          42          31      135.48     4     1      v England
# 347    35          35          33      106.06     4     0   v Bangladesh
# 348   DNB           -           -           -     -     -    v Sri Lanka
# 349    50          50          72       69.44     1     1  v New Zealand
#
#          ground        date  odi_number
# 345  Manchester  27/06/2019  ODI # 4175
# 346  Birmingham  30/06/2019  ODI # 4179
# 347  Birmingham  02/07/2019  ODI # 4182
# 348       Leeds  06/07/2019  ODI # 4187
# 349  Manchester  09/07/2019  ODI # 4190

# %%
#Data cleaning- Opposite name says 'v Aus' etc, we can remove 'v '
df['opposition'] = df['opposition'].str.replace('v ','', regex=False)
# df['Opposition'] = df['opposition'].apply(lambda x: x[2: ])
#regex=False means that the first string('v ') is not a regex, but a literal String
df
# Out:
#     score runs_scored balls_faced strike_rate fours sixes   opposition  \
# 0       0           0           1           0     0     0   Bangladesh
# 1      12          12          11      109.09     2     0   Bangladesh
# 2      7*           7           2         350     0     1   Bangladesh
# 3       3           3           7       42.85     0     0     Pakistan
# 4     148         148         123      120.32    15     4     Pakistan
# ..    ...         ...         ...         ...   ...   ...          ...
# 345   56*          56          61        91.8     3     2  West Indies
# 346   42*          42          31      135.48     4     1      England
# 347    35          35          33      106.06     4     0   Bangladesh
# 348   DNB           -           -           -     -     -    Sri Lanka
# 349    50          50          72       69.44     1     1  New Zealand
#
#             ground        date  odi_number
# 0       Chattogram  23/12/2004  ODI # 2199
# ...

# %%
df['date'] = pd.to_datetime(df['date'], dayfirst= True)
df['Year'] = df['date'].dt.year.astype(int)

# %%
df
# Out:
#     score runs_scored balls_faced strike_rate fours sixes   opposition  \
# 0       0           0           1           0     0     0   Bangladesh
# 1      12          12          11      109.09     2     0   Bangladesh
# 2      7*           7           2         350     0     1   Bangladesh
# 3       3           3           7       42.85     0     0     Pakistan
# 4     148         148         123      120.32    15     4     Pakistan
# ..    ...         ...         ...         ...   ...   ...          ...
# 345   56*          56          61        91.8     3     2  West Indies
# 346   42*          42          31      135.48     4     1      England
# 347    35          35          33      106.06     4     0   Bangladesh
# 348   DNB           -           -           -     -     -    Sri Lanka
# 349    50          50          72       69.44     1     1  New Zealand
#
#             ground       date  odi_number  Year
# 0       Chattogram 2004-12-23  ODI # 2199  2004
# ...

# %%
df.Year  # or df['Year']
# Out:
# 0      2004
# 1      2004
# 2      2004
# 3      2005
# 4      2005
#        ...
# 345    2019
# 346    2019
# 347    2019
# 348    2019
# 349    2019
# Name: Year, Length: 350, dtype: int64

# %%
# batting avg = total runs scored /(Innigs count - not outs count)

df['score'] = df['score'].apply(str)
df['not_out'] = np.where(df['score'].str.endswith('*'),1,0)
df
# Out:
#     score runs_scored balls_faced strike_rate fours sixes   opposition  \
# 0       0           0           1           0     0     0   Bangladesh
# 1      12          12          11      109.09     2     0   Bangladesh
# 2      7*           7           2         350     0     1   Bangladesh
# 3       3           3           7       42.85     0     0     Pakistan
# 4     148         148         123      120.32    15     4     Pakistan
# ..    ...         ...         ...         ...   ...   ...          ...
# 345   56*          56          61        91.8     3     2  West Indies
# 346   42*          42          31      135.48     4     1      England
# 347    35          35          33      106.06     4     0   Bangladesh
# 348   DNB           -           -           -     -     -    Sri Lanka
# 349    50          50          72       69.44     1     1  New Zealand
#
#             ground       date  odi_number  Year  not_out
# 0       Chattogram 2004-12-23  ODI # 2199  2004        0
# ...

# %%
#Removing odi_number column from the df.
# df.drop(columns='odi_number',inplace=True)
# df

# %%
df_new = df.loc[((df['score']!='DNB') & (df['score'] != "TDNB")),'runs_scored':]
df_new
# Out:
#     runs_scored balls_faced strike_rate fours sixes   opposition  \
# 0             0           1           0     0     0   Bangladesh
# 1            12          11      109.09     2     0   Bangladesh
# 2             7           2         350     0     1   Bangladesh
# 3             3           7       42.85     0     0     Pakistan
# 4           148         123      120.32    15     4     Pakistan
# ..          ...         ...         ...   ...   ...          ...
# 344          28          52       53.84     3     0  Afghanistan
# 345          56          61        91.8     3     2  West Indies
# 346          42          31      135.48     4     1      England
# 347          35          33      106.06     4     0   Bangladesh
# 349          50          72       69.44     1     1  New Zealand
#
#             ground       date  odi_number  Year  not_out
# 0       Chattogram 2004-12-23  ODI # 2199  2004        0
# 1            Dhaka 2004-12-26  ODI # 2201  2004        0
# ...

# %%
# fixing the data types of numerical columns
df_new.info()
df_new['runs_scored'] =df_new['runs_scored'].astype(int)
df_new['balls_faced'] =df_new['balls_faced'].astype(int)
df_new['strike_rate'] =df_new['strike_rate'].astype(float)
df_new['fours'] =df_new['fours'].astype(int)
df_new['sixes'] =df_new['sixes'].astype(int)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 297 entries, 0 to 349
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   runs_scored  297 non-null    object
#  1   balls_faced  297 non-null    object
#  2   strike_rate  297 non-null    object
#  3   fours        297 non-null    object
#  4   sixes        297 non-null    object
#  5   opposition   297 non-null    object
#  6   ground       297 non-null    object
#  7   date         297 non-null    datetime64[ns]
#  8   odi_number   297 non-null    object
#  9   Year         297 non-null    int64
#  10  not_out      297 non-null    int64
# dtypes: datetime64[ns](1), int64(2), object(8)
# memory usage: 27.8+ KB

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 297 entries, 0 to 349
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   runs_scored  297 non-null    int64
#  1   balls_faced  297 non-null    int64
#  2   strike_rate  297 non-null    float64
#  3   fours        297 non-null    int64
#  4   sixes        297 non-null    int64
#  5   opposition   297 non-null    object
#  6   ground       297 non-null    object
#  7   date         297 non-null    datetime64[ns]
#  8   odi_number   297 non-null    object
#  9   Year         297 non-null    int64
#  10  not_out      297 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(3)
# memory usage: 27.8+ KB

# %%
first_match_date = df['date'].dt.date.min().strftime('%B %d, %Y')
print(first_match_date)

last_match_date = df['date'].dt.date.max().strftime('%B %d, %Y')
print(last_match_date)
# Out:
# December 23, 2004
# July 09, 2019

# %%
numOfmatches = df.shape[0]
print(f"Number of matches : {numOfmatches}")

numOfinnings = df_new.shape[0]
print(f"Number of innings : {numOfinnings}")

not_outs = df_new['not_out'].sum()
print(f"Number of innings : {not_outs}")

runs_scored = df_new['runs_scored'].sum()
print(f"runs_scored : {runs_scored}")

balls_faced   = df_new['balls_faced'].sum()
print(f"balls_faced   : {balls_faced}")
# Out:
# Number of matches : 350
# Number of innings : 297
# Number of innings : 84
# runs_scored : 10773
# balls_faced   : 12303

# %%
# batting avg = total runs scored /(Innigs count - not outs count)
career_sk = runs_scored / balls_faced
print("Career strike: {:.2f}".format(career_sk))

career_avg = runs_scored /(numOfinnings - not_outs )
print("Career avg: {:.2f}".format(career_avg))
# Out:
# Career strike: 0.88
# Career avg: 50.58

# %%
hundread = (df_new['runs_scored']>100).sum()
print(hundread)
# Out:
# 10

# %%
fifties = (df_new['runs_scored'] >= 50).sum()
fifties
# Out:
# 83

# %%
fours = df_new['fours'].sum()
fours
# Out:
# 826

# %%
sixes = df_new['sixes'].sum()
sixes
# Out:
# 229

# %%
#no. of matches played against different opposition
#count the occurence of each unique value in the 'opposition' column
#opposition count will be a series with a labelled index as opposition
opposition_count = df['opposition'].value_counts()
opposition_count
# Out:
# opposition
# Sri Lanka       67
# Australia       55
# England         48
# West Indies     39
# South Africa    37
# Pakistan        36
# New Zealand     28
# Bangladesh      21
# Zimbabwe         6
# Africa XI        3
# Hong Kong        2
# Ireland          2
# Afghanistan      2
# Bermuda          1
# Scotland         1
# Netherlands      1
# U.A.E.           1
# Name: count, dtype: int64

# %%
#Plot the counts as the bar plot
opposition_count.plot(kind='bar', title='No. of matches against diff oppositions', figsize=(8, 5))
plt.show()

# %%
#Runs scored against each team
#group the df by opposition column
grouped_by_opposition = df_new.groupby('opposition')
#Sum the runs scored columns for each group
sum_of_runs_scored = grouped_by_opposition['runs_scored'].sum()
sum_of_runs_scored
# Out:
# opposition
# Afghanistan       36
# Africa XI        174
# Australia       1660
# Bangladesh       569
# Bermuda           29
# England         1546
# Hong Kong        109
# Ireland           34
# Netherlands       19
# New Zealand      940
# Pakistan        1231
# South Africa     830
# Sri Lanka       2383
# West Indies     1005
# Zimbabwe         208
# Name: runs_scored, dtype: int64

# %%
#sum of run scored is a series with a labelled index, which is opposition
#convert it into a df and remove the index
runs_scored_by_opposition = pd.DataFrame(sum_of_runs_scored).reset_index()
runs_scored_by_opposition.plot(kind='bar', x='opposition', y='runs_scored', title='Runs scored by opposition', figsize=(8, 5))
plt.show()

# %%
#Creating New Book

# %%
#Creating a series nfrom  python list
myindex = ['USA','Canada','Mexico']
mydata = [1776,1867,1821]
myser = pd.Series(data=mydata)
myser
# Out:
# 0    1776
# 1    1867
# 2    1821
# dtype: int64

# %%
myser = pd.Series(data=mydata,index=myindex)
myser
# Out:
# USA       1776
# Canada    1867
# Mexico    1821
# dtype: int64

# %%
#Creating a series from numpy array
#First create a numpy array using the earlier list
ran_data = np.random.randint(0,100,4)
ran_data
# Out:
# array([28, 21, 11, 19])

# %%
name = ['Alice', 'Bob', 'Charlie', 'David']
ages = pd.Series(ran_data, index=name)
ages
# Out:
# Alice      28
# Bob        21
# Charlie    11
# David      19
# dtype: int64

# %%
#creating a series from the dictionary
ages = {'Alice': 25, 'Bob': 30, 'Charlie': 35, 'David': 40}
ages = pd.Series(ages)
ages
# Out:
# Alice      25
# Bob        30
# Charlie    35
# David      40
# dtype: int64

# %%
#Using named index
#Imaginary sales data for 1st and 2nd Q for a global company
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100,'China':500, 'India': 210,'USA': 260}

# %%
#convert into pandas Series
sales_q1 = pd.Series(q1)
sales_q2 = pd.Series(q2)
sales_q1
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
#Call values based on named index
sales_q1['Japan']
# Out:
# 80

# %%
# (COMMON MISTAKES)  wrong name , extra space , case sensitive dO IT ON YOUR OWN HW

# %%
#gRAB just the index keys
sales_q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
#Can perform operations broadcasted across entire series
sales_q1 * 2
# Out:
# Japan    160
# China    900
# India    400
# USA      500
# dtype: int64

# %%
sales_q2 / 100
# Out:
# Brazil    1.0
# China     5.0
# India     2.1
# USA       2.6
# dtype: float64

# %%
#Notice how pandas inform you of mismatch with match
print(sales_q1 + sales_q2)
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
#you can fill nan with any data type values
sales_q2.add(sales_q2.fillna(value=0),axis=0)
# Out:
# Brazil     200
# China     1000
# India      420
# USA        520
# dtype: int64

# %%
# Boxplot of runs agains various opposotions
sns.boxplot(x='opposition', y='runs_scored', data=df_new)     # outliers - Extreme Data point (unko higlight krta h box plot)
plt.show()

# %%
# Look Crowded - let us retain om;y major countries

opposition_list = ['England','Australia','West Indies', 'South Africa','New Zealand', 'Pakistan','Sri Lanka','Bangladesh']

# %%
# Filter row where oppositon is in the list
df_new_filtered = df_new[df_new['opposition'].isin(opposition_list)]
df_new_filtered
#\
# Out:
#      runs_scored  balls_faced  strike_rate  fours  sixes   opposition  \
# 0              0            1         0.00      0      0   Bangladesh
# 1             12           11       109.09      2      0   Bangladesh
# 2              7            2       350.00      0      1   Bangladesh
# 3              3            7        42.85      0      0     Pakistan
# 4            148          123       120.32     15      4     Pakistan
# ..           ...          ...          ...    ...    ...          ...
# 343            1            2        50.00      0      0     Pakistan
# 345           56           61        91.80      3      2  West Indies
# 346           42           31       135.48      4      1      England
# 347           35           33       106.06      4      0   Bangladesh
# 349           50           72        69.44      1      1  New Zealand
#
#             ground       date  odi_number  Year  not_out
# 0       Chattogram 2004-12-23  ODI # 2199  2004        0
# ...

# %%
# sort thr filter data in decending order of run scored
df_new_filtered = df_new_filtered.sort_values(by='runs_scored', ascending=False)
df_new_filtered
#
# Out:
#      runs_scored  balls_faced  strike_rate  fours  sixes    opposition  \
# 21           183          145       126.20     15     10     Sri Lanka
# 4            148          123       120.32     15      4      Pakistan
# 228          139          121       114.87     12      5     Australia
# 284          134          122       109.83     10      6       England
# 146          124          107       115.88      9      3     Australia
# ..           ...          ...          ...    ...    ...           ...
# 74             0            4         0.00      0      0  South Africa
# 273            0            3         0.00      0      0     Australia
# 171            0            1         0.00      0      0     Australia
# 223            0            4         0.00      0      0       England
# 0              0            1         0.00      0      0    Bangladesh
#
#             ground       date  odi_number  Year  not_out
# 21          Jaipur 2005-10-31  ODI # 2290  2005        1
# ...

# %%
#  redraw Boxplot of runs agains various opposotions
sns.boxplot(x='opposition', y='runs_scored', data = df_new_filtered)     # outliers - Extreme Data point (unko higlight krta h box plot)
plt.xticks(rotation=45)
plt.show()

# %%
# Histogram (distplot) with and without kde (kernel density estimate)
sns.displot(data = df_new_filtered, x = 'runs_scored', kde=True)
plt.show()

# %%
sns.histplot(data = df_new_filtered, x = 'runs_scored', kde=True)
plt.show()
#

# %%
sns.set(style = 'darkgrid')
sns.histplot(data = df_new_filtered, x = 'runs_scored',bins=110)
plt.show()
#

# %%
sns.set(style = 'darkgrid')
sns.histplot(data = df_new_filtered, x = 'runs_scored',bins=10)
plt.show()

# %%
# KDE plot
plt.figure(figsize=(10, 8))
sns.set(style = 'darkgrid')
sns.kdeplot(data = df_new_filtered, x = 'runs_scored')
plt.show()

# %%
# KDE plot with cumulative probability
plt.figure(figsize=(10,5))
sns.set(style='darkgrid')
sns.kdeplot(data = df_new , x = 'runs_scored', cumulative=True)
plt.show()

# %%
# joint plot
plt.figure(figsize=(10,10))
sns.jointplot(data = df_new_filtered, x = 'runs_scored', y = 'balls_faced')
plt.show()

# %%
# joint plot
plt.figure(figsize=(50,10))
sns.jointplot(data = df_new_filtered, x = 'balls_faced', y = 'runs_scored', kind = 'scatter')
plt.show()

# %%
# calculate the corelation matrix
corr = df_new_filtered[['balls_faced', 'runs_scored']].corr()
corr
# Out:
#              balls_faced  runs_scored
# balls_faced     1.000000     0.895767
# runs_scored     0.895767     1.000000

# %%
#  Create Heatmap
plt.figure(figsize=(10,10))
sns.heatmap(data = corr, annot = True , cmap = 'viridis',square = True , fmt = '.2f')
plt.title('Correlation Matrix between ball faces and runs scored ')
plt.show()

# %%
#  Show the carrer strike rate against each opposition



grouped_by_opposition = df_new_filtered.groupby('opposition')
grouped_by_opposition

# %%
#Sum the runs scored columns for each group
sum_of_runs_scored = grouped_by_opposition.agg({'balls_faced': 'sum', 'runs_scored': 'sum'})
sum_of_runs_scored
# Out:
#               balls_faced  runs_scored
# opposition
# Australia            2052         1660
# Bangladesh            682          569
# England              1758         1546
# New Zealand          1140          940
# Pakistan             1361         1231
# South Africa          950          830
# Sri Lanka            2645         2383
# West Indies          1108         1005

# %%
#Assigin the result to df_strike_rate

df_strike_rate = sum_of_runs_scored
df_strike_rate
# Out:
#               balls_faced  runs_scored
# opposition
# Australia            2052         1660
# Bangladesh            682          569
# England              1758         1546
# New Zealand          1140          940
# Pakistan             1361         1231
# South Africa          950          830
# Sri Lanka            2645         2383
# West Indies          1108         1005

# %%
#Calculate_strike rate
df_strike_rate['strike_rate'] = df_strike_rate['runs_scored'] / df_strike_rate['balls_faced'] * 100
df_strike_rate
# Out:
#               balls_faced  runs_scored  strike_rate
# opposition
# Australia            2052         1660    80.896686
# Bangladesh            682          569    83.431085
# England              1758         1546    87.940842
# New Zealand          1140          940    82.456140
# Pakistan             1361         1231    90.448200
# South Africa          950          830    87.368421
# Sri Lanka            2645         2383    90.094518
# West Indies          1108         1005    90.703971

# %%
#Bad Graph - strike rate scale is different from runs, scored and balls
sns.heatmap(df_strike_rate, linewidth=0.5, annot= True, fmt=".0f", cmap= 'viridis')
plt.show()

# %%
df.sample(5)
# Out:
#     score runs_scored balls_faced strike_rate fours sixes   opposition  \
# 307   18*          18          21       85.71     3     0  New Zealand
# 309    65          65          87       74.71    10     2    Sri Lanka
# 213    36          36          55       65.45     1     3     Pakistan
# 207    11          11          16       68.75     2     0    Sri Lanka
# 272    23          23           9      255.55     2     2    Australia
#
#          ground       date  odi_number  Year  not_out
# 307        Pune 2017-10-25  ODI # 3931  2017        1
# 309  Dharamsala 2017-12-10  ODI # 3939  2017        0
# 213       Delhi 2013-01-06  ODI # 3316  2013        0
# 207  Hambantota 2012-07-24  ODI # 3292  2012        0
# 272   Melbourne 2016-01-17  ODI # 3725  2016        0

# %% [markdown]
# **#   <h1>Day 4 More Work in this csv</h1> **

# %%
df2 = df_new.groupby('opposition')[['runs_scored', 'sixes', 'fours']].sum().reset_index()
df2['runs_in_boundries'] = (df2['fours'] * 4) + (df2['sixes'] * 6)
df2
df2 = df2[df2['runs_scored'] > 200]
df2
# Out:
#       opposition  runs_scored  sixes  fours  runs_in_boundries
# 2      Australia         1660     33    112                646
# 3     Bangladesh          569      3     49                214
# 5        England         1546     34    129                720
# 9    New Zealand          940     20     73                412
# 10      Pakistan         1231     25    108                582
# 11  South Africa          830     18     67                376
# 12     Sri Lanka         2383     45    182                998
# 13   West Indies         1005     28     63                420
# 14      Zimbabwe          208      9     11                 98

# %%
plt.bar(df2['opposition'], df2['runs_in_boundries'])
# Out:
# <BarContainer object of 9 artists>

# %%
#Stacked bar plot
plt.figure(figsize=(10,6))
plt.bar(df2['opposition'], df2['runs_scored'], label='Runs Scored')
plt.bar(df2['opposition'], df2['runs_in_boundries'], bottom=df2['runs_scored'], label='Runs In Boundries')
plt.xlabel('Oppostion')
plt.ylabel('Runs')
plt.title('Runs scored  and runs in boundries by opposition')
plt.legend()

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
